# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('vgsales.csv')

# %%
df2 = df.set_index('Platform')
df2
# Out:
#                                                       Name    Year  Genre  \
# Platform
# Wii                                             Wii Sports  2006.0      1
# NES                                      Super Mario Bros.  1985.0      2
# Wii                                         Mario Kart Wii  2008.0      3
# Wii                                      Wii Sports Resort  2009.0      1
# GB                                Pokemon Red/Pokemon Blue  1996.0      4
# ...                                                    ...     ...    ...
# GBA                     Woody Woodpecker in Crazy Castle 5  2002.0      2
# GC                           Men in Black II: Alien Escape  2003.0      7
# PS2       SCORE International Baja 1000: The Official Game  2008.0      3
# DS                                              Know How 2  2010.0      5
# GBA                                       Spirits & Spells  2003.0      2
#
# ...

# %%
df2.loc['PS4']
# Out:
#                                                        Name    Year  Genre  \
# Platform
# PS4                               Call of Duty: Black Ops 3  2015.0      7
# PS4                                      Grand Theft Auto V  2014.0      9
# PS4                                                 FIFA 16  2015.0      1
# PS4                            Star Wars Battlefront (2015)  2015.0      7
# PS4                          Call of Duty: Advanced Warfare  2014.0      7
# ...                                                     ...     ...    ...
# PS4                            Dynasty Warriors: Eiketsuden  2016.0      9
# PS4                                                 Paragon  2016.0      9
# PS4                                             Chaos;Child  2015.0     11
# PS4       God Eater Off Shot: Tachibana Sakuya-hen Twin ...  2016.0      9
# PS4                           Farming 2017 - The Simulation  2016.0      8
#
# ...

# %%
x = df2.loc['PS4'].sort_values('Global_Sales', ascending = False).head(10)
x
# Out:
#                                     Name    Year  Genre  \
# Platform
# PS4            Call of Duty: Black Ops 3  2015.0      7
# PS4                   Grand Theft Auto V  2014.0      9
# PS4                              FIFA 16  2015.0      1
# PS4         Star Wars Battlefront (2015)  2015.0      7
# PS4       Call of Duty: Advanced Warfare  2014.0      7
# PS4                            Fallout 4  2015.0      4
# PS4                              FIFA 15  2014.0      1
# PS4                              Destiny  2014.0      7
# PS4                              FIFA 17  2016.0      1
# PS4                       The Last of Us  2014.0      9
#
#                             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# PS4                        Activision      5.77      5.81      0.35
# PS4              Take-Two Interactive      3.80      5.81      0.36
# PS4                   Electronic Arts      1.11      6.06      0.06
# ...

# %%
df2.loc['PS4'].max()
# Out:
# Name            inFAMOUS: Second Son
# Year                          2017.0
# Genre                             12
# Publisher                       Yeti
# NA_Sales                        5.77
# EU_Sales                        6.06
# JP_Sales                        0.48
# Other_Sales                     2.31
# Global_Sales                   14.24
# dtype: object

# %%
x['JP_Sales_EU_Sales'] = x['JP_Sales'] + x['EU_Sales']
x['JP_Sales_EU_Sales']
# Out:
# Platform
# PS4    6.16
# PS4    6.17
# PS4    6.12
# PS4    3.51
# PS4    3.44
# PS4    3.39
# PS4    4.34
# PS4    2.21
# PS4    3.81
# PS4    1.94
# Name: JP_Sales_EU_Sales, dtype: float64

# %%
x
# Out:
#                                     Name    Year  Genre  \
# Platform
# PS4            Call of Duty: Black Ops 3  2015.0      7
# PS4                   Grand Theft Auto V  2014.0      9
# PS4                              FIFA 16  2015.0      1
# PS4         Star Wars Battlefront (2015)  2015.0      7
# PS4       Call of Duty: Advanced Warfare  2014.0      7
# PS4                            Fallout 4  2015.0      4
# PS4                              FIFA 15  2014.0      1
# PS4                              Destiny  2014.0      7
# PS4                              FIFA 17  2016.0      1
# PS4                       The Last of Us  2014.0      9
#
#                             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# PS4                        Activision      5.77      5.81      0.35
# PS4              Take-Two Interactive      3.80      5.81      0.36
# PS4                   Electronic Arts      1.11      6.06      0.06
# ...

# %%
df
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#        Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# # exercise 6

# %%
#How many games were released for XOne in 2016? Which was the top selling in Europe?
df.groupby('Year').count()
# Out:
#         Name  Platform  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Year
# 1980.0     9         9      9          9         9         9         9
# 1981.0    46        46     46         46        46        46        46
# 1982.0    36        36     36         36        36        36        36
# 1983.0    17        17     17         17        17        17        17
# 1984.0    14        14     14         14        14        14        14
# 1985.0    14        14     14         14        14        14        14
# 1986.0    21        21     21         21        21        21        21
# 1987.0    16        16     16         16        16        16        16
# 1988.0    15        15     15         15        15        15        15
# 1989.0    17        17     17         17        17        17        17
# 1990.0    16        16     16         16        16        16        16
# 1991.0    41        41     41         41        41        41        41
# ...

# %%
df.loc[(df['Platform']== 'XOne') & (df['Year']==2016.0)]
# Out:
#                                                     Name Platform    Year  \
# 845                            Tom Clancy's The Division     XOne  2016.0
# 1224                                             FIFA 17     XOne  2016.0
# 2434                                     Far Cry: Primal     XOne  2016.0
# 2444                                           Overwatch     XOne  2016.0
# 2505                                       Madden NFL 17     XOne  2016.0
# 2991                                         Doom (2016)     XOne  2016.0
# 3145                                            NBA 2K17     XOne  2016.0
# 3927                                       Quantum Break     XOne  2016.0
# 4430                Plants vs. Zombies: Garden Warfare 2     XOne  2016.0
# 4820                                     EA Sports UFC 2     XOne  2016.0
# 5015                                     Forza Horizon 3     XOne  2016.0
# 5268                                      Dark Souls III     XOne  2016.0
# ...

# %%
#df.loc[(df['Platform']== 'XOne') & (df['Year']==2016.0)]

df.loc[(df['Platform']== 'XOne') & (df['Year']==2016.0)]['Name'].count()
# Out:
# 54

# %%
df.loc[(df['Platform']== 'XOne') & (df['Year']==2016.0)].count()
# Out:
# Name            54
# Platform        54
# Year            54
# Genre           54
# Publisher       54
# NA_Sales        54
# EU_Sales        54
# JP_Sales        54
# Other_Sales     54
# Global_Sales    54
# dtype: int64

# %% [markdown]
# # exercise 7

# %%
df['Platform'] = df['Platform'].replace('XOne', 'X Box One')

# %%
df.loc[(df['Platform']=='X Box One')]
# Out:
#                                  Name   Platform    Year  Genre  \
# 101         Call of Duty: Black Ops 3  X Box One  2015.0      7
# 193    Call of Duty: Advanced Warfare  X Box One  2014.0      7
# 197                Grand Theft Auto V  X Box One  2014.0      9
# 260                 Halo 5: Guardians  X Box One  2015.0      7
# 287                         Fallout 4  X Box One  2015.0      4
# ...                               ...        ...     ...    ...
# 16530        Sébastien Loeb Rally Evo  X Box One  2016.0      3
# 16531                   Hitman (2016)  X Box One  2016.0      9
# 16562                    Mighty No. 9  X Box One  2016.0      2
# 16569              Resident Evil 4 HD  X Box One  2016.0      7
# 16576               Rugby Challenge 3  X Box One  2016.0      1
#
#                     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 101                Activision      4.52      2.09      0.01         0.67
# ...

# %% [markdown]
# # How many PC games have higher sales than 3 million global sales?
# exercise 8

# %%
pc_games = df.loc[(df['Platform']=='PC') & (df['Global_Sales'] > 3.0)]['Name'].count()

print('the number of PC games that have higher sales than 3 million global sales are:', pc_games)
# Out:
# the number of PC games that have higher sales than 3 million global sales are: 12
